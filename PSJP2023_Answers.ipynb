# %% [markdown]
# # PSJP's introduction to Python for Journalism
#
#
# Welcome! This workbook will walk you through a few key python elements, and have some data challenges to get your hands dirty in computational journalism.
#
#
#
#
# > **Step #1** is to make a copy of this notebook that you can edit and save. Go to `file` -> `Save a copy in Drive` and it will open a copy of this file in a new tab. This copy is private to you so make all the edits and notes you'd like.
#
#
#
#
# While you work through these exercises, you're going to be in a small group. These other people are here so you can talk through what you're doing, ask lots of questions, and problem solve together. The best examples of computational journalism are created collaboratively, and are better because of it. It doesn't matter how far you get in this file, so just enjoy the ride with your peers. I (Eve) will be hopping around to answer questions and guide you. When you get stuck, don't be afraid to google your problem or error, there's a huge online community of problem solvers for programming.
#
#
# There's 3 parts to this exercise, feel free to hop around and attack what is interesting to you and your team.
#
#
# 1. Intro To Python
# 2. Challenge #1: I Spy Pandas
# 3. Challenge #2: Cluster? I hardly know her (feat. Machine Learning!)
#
#
#
#
# > If you already know python, feel free to skip ahead to challenge #1 or challenge #2
#
#
# > If this is your first time coding, know that this is HARD. Learning a programming language isn't easy and the goal here is just to expose you to some basics. Have fun with it!
#
#
#
#
# ## About this document
#
#
# This file is a Jupyter Notebook and we will be working in Python, a powerful generalist programming language. There's many tools and languages out there for this type of work, this is just one. The way this notebook works is that there are some "blocks'' for text and some for code.
#
#
# Text is written in something called Markdown. You can double click on this block to see what it looks like and if you're curious you can [learn how to use it here](https://www.markdowntutorial.com/)
#
#
# Code blocks contain Python expressions, which you can run and see in your browser immediately by pressing the play button on the left or pressing `Shift` + `Enter` with the block focused.
#
#
# ### Enough talk, let's try running some code.

# %%
35 + 125
# Out:
# 160

# %% [markdown]
# Your first python expression! I'm so proud. At its core coding is just using a big fancy calculator. You can also save values to **variables**, which are named entities that hold data.

# %%
value = 35

value + 125
# Out:
# 160

# %% [markdown]
# You can get an idea of what is inside a variable by using the `type()` **function**. A **function** is a set of steps that are defined to do something based on an input. This one tells you what type of data is inside a variable.

# %%
type(value)
# Out:
# int

# %% [markdown]
# `int` is short for **Integer**, which just means a whole number. There are a few other types of basic data in Python, like...
#
#
#
#
# * **floats** - short for "floating point number" which just means it has a decimal point
# * **strings** - any line of text, like `"hello world"`, `'PSJP!'` these are can be defined in python with single or double quotation marks
# * **booleans** - `True` or `False` values
#
#
#
#
# These basic types, create the foundation for all computation and can be organized in many different ways which we call **data structures**.
#
#
# Below are some examples of these data types in use. In your team run each one of them and see if you can understand what's happening. It's okay if something doesn't make sense, make a note of it in a text block and if there's time at the end we can talk about it

# %%
#this is a data structure called a list, its a type of data structure
# you can access a specific value in the list with []

arr = [1, 2, 3, 4, 5]
arr[2]
# Out:
# 3

# %%
#this is a for loop, one of its uses is for moving through the elements of an array
for number in arr:
  print(3 == number)
# Out:
# False
# False
# True
# False
# False

# %%
cats_are_cool = True
dogs_are_cool = True
fish_suck = False

likes_animals = cats_are_cool & dogs_are_cool and not fish_suck #'and' can be written as 'and' or '&'
likes_animals
# Out:
# True

# %%
fish_suck = True

likes_animals = cats_are_cool & dogs_are_cool and not fish_suck
likes_some_animals = cats_are_cool | dogs_are_cool or not fish_suck #'or' can be written as 'or' or '|'

print("likes_animals?", likes_animals)
print("likes_some_animals?", likes_some_animals)
# Out:
# likes_animals? False
# likes_some_animals? True

# %%
"fish " + "rule" + "!!!!"
# Out:
# 'fish rule!!!!'

# %%
"fish" * 10
# Out:
# 'fishfishfishfishfishfishfishfishfishfish'

# %% [markdown]
# **Before moving on to the first challenge, feel free to play around here some more, define your own variables, test what happens when you change some of the values in the above expressions, and write new expressions. This stuff is the foundation for understanding anything you wanna build with Python (or any programming language), and the examples above just scratch the surface**

# %% [markdown]
# # Challenge 1: I Spy Pandas
# One way to analyze data in Python is with a **library** called **Pandas**, a **library** is just a set of functions and objects from another developer that builds on the core python capabilities that we learned about earlier. Basically, this means less work for bigger outcomes.
#
#
# First we need to load the library and the data. This data is scraped from OpenStreets with some added address info I accessed through a MapBox API. It contains information on 44470 public bathrooms, most of which are in the USA with a few in the Caribbean, Canada, and Mexico.

# %%
import pandas as pd
df = pd.read_json('https://raw.githubusercontent.com/EveWashington/PSJP-Intro/main/bathroom.json') # this may take a sec
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Pandas** stores data in what's called **dataframes**, we can preview the data by calling a few functions:

# %%
df.info(verbose=True, show_counts=True)
#this gives a high level look at the structures of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44470 entries, 0 to 44469
# Data columns (total 380 columns):
#  #    Column                                 Non-Null Count  Dtype
# ---   ------                                 --------------  -----
#  0    id                                     44470 non-null  int64
#  1    lat                                    44470 non-null  float64
#  2    lon                                    44470 non-null  float64
#  3    state                                  44135 non-null  object
#  4    address                                44468 non-null  object
#  5    city                                   42851 non-null  object
#  6    zip                                    39989 non-null  object
#  7    country                                44155 non-null  object
#  8    amenity                                44470 non-null  object
#  9    toilets:wheelchair                     148 non-null    object
#  10   wheelchair                             5059 non-null   object
#  11   created_by                             93 non-null     object
#  12   note                                   421 non-null    object
#  13   access                                 8097 non-null   object
#  14   female                                 2707 non-null   object
#  15   male                                   2693 non-null   object
#  16   source                                 2944 non-null   object
#  17   toilets:disposal                       12157 non-null  object
#  18   level                                  1244 non-null   object
#  19   fee                                    4684 non-null   object
#  20   toilets:position                       932 non-null    object
#  21   unisex                                 4661 non-null   object
#  22   changing_table                         2374 non-null   object
#  23   check_date                             831 non-null    object
#  24   operator                               2016 non-null   object
#  25   building                               553 non-null    object
#  26   designation                            130 non-null    object
#  27   ele                                    53 non-null     float64
#  28   gnis:Class                             1 non-null      object
#  29   gnis:County                            1 non-null      object
#  30   gnis:County_num                        1 non-null      float64
#  31   gnis:ST_alpha                          1 non-null      object
#  32   gnis:ST_num                            1 non-null      float64
#  33   gnis:id                                1 non-null      float64
#  34   import_uuid                            1 non-null      object
#  35   is_in                                  9 non-null      object
#  36   name                                   1562 non-null   object
#  37   phone                                  70 non-null     object
#  38   toilets:handwashing                    1217 non-null   object
#  39   layer                                  64 non-null     float64
#  40   drinking_water                         857 non-null    object
#  41   description                            436 non-null    object
#  42   odbl                                   1 non-null      object
#  43   source_ref                             38 non-null     object
#  44   opening_hours                          607 non-null    object
#  45   highway                                25 non-null     object
#  46   addr:city                              468 non-null    object
#  47   addr:housenumber                       146 non-null    object
#  48   addr:state                             110 non-null    object
#  49   addr:street                            391 non-null    object
#  50   tourism                                676 non-null    object
#  51   women                                  7 non-null      object
#  52   lastcheck:note                         1 non-null      object
#  53   portable                               987 non-null    object
#  54   indoor                                 367 non-null    object
#  55   hour_off                               1 non-null      object
#  56   hour_on                                1 non-null      object
#  57   gnis:county_id                         4 non-null      float64
#  58   gnis:created                           5 non-null      object
#  59   gnis:feature_id                        6 non-null      float64
#  60   gnis:state_id                          3 non-null      float64
#  61   wikidata                               3 non-null      object
#  62   leisure                                622 non-null    object
#  63   website                                73 non-null     object
#  64   seasonal                               183 non-null    object
#  65   old_name                               8 non-null      object
#  66   operator:wikidata                      40 non-null     object
#  67   capacity                               108 non-null    object
#  68   supervised                             29 non-null     object
#  69   toilets:paper_supplied                 107 non-null    object
#  70   wheelchair:description:en              2 non-null      object
#  71   fixme                                  145 non-null    object
#  72   board_type                             2 non-null      object
#  73   information                            10 non-null     object
#  74   toilets:type                           325 non-null    object
#  75   shower                                 111 non-null    object
#  76   FIXME                                  6 non-null      object
#  77   mapillary                              29 non-null     object
#  78   wpt_description                        7 non-null      object
#  79   wpt_symbol                             8 non-null      object
#  80   addr:country                           197 non-null    object
#  81   ref                                    104 non-null    object
#  82   brand                                  11 non-null     object
#  83   brand:wikidata                         7 non-null      object
#  84   operator:type                          794 non-null    object
#  85   addr:postcode                          128 non-null    object
#  86   internet_access                        15 non-null     object
#  87   public                                 3 non-null      object
#  88   source:location                        5 non-null      object
#  89   operator:short                         4 non-null      object
#  90   operator:wikipedia                     6 non-null      object
#  91   bench                                  1 non-null      object
#  92   bin                                    4 non-null      object
#  93   bus                                    1 non-null      object
#  94   public_transport                       1 non-null      object
#  95   shelter                                2 non-null      object
#  96   historic                               5 non-null      object
#  97   GPS_Mission_Preparation                1 non-null      object
#  98   private                                2 non-null      object
#  99   handicap                               5 non-null      object
#  100  shop                                   8 non-null      object
#  101  toilets                                73 non-null     object
#  102  laundry                                5 non-null      object
#  103  inside                                 2 non-null      object
#  104  disability_access                      727 non-null    object
#  105  gender_access                          817 non-null    object
#  106  operational_status                     655 non-null    object
#  107  operator_type                          316 non-null    object
#  108  entrance                               50 non-null     object
#  109  wheelchair:description                 14 non-null     object
#  110  quantity                               3 non-null      float64
#  111  hfac_type                              1 non-null      object
#  112  operator_id                            10 non-null     object
#  113  source:health_facility                 1 non-null      object
#  114  access:conditional                     7 non-null      object
#  115  operational_status_quality             431 non-null    object
#  116  photo_url                              4 non-null      object
#  117  tunnel                                 2 non-null      object
#  118  landuse                                1 non-null      object
#  119  contact_person                         72 non-null     object
#  120  nps:verified                           1 non-null      object
#  121  amenity_1                              17 non-null     object
#  122  operator_installation                  8 non-null      object
#  123  addr:full                              33 non-null     object
#  124  addr:housename                         17 non-null     object
#  125  IOM:project                            166 non-null    object
#  126  status                                 179 non-null    object
#  127  toilets:access                         133 non-null    object
#  128  toilets:basement                       99 non-null     object
#  129  toilets:cleaning                       79 non-null     object
#  130  toilets:durability                     108 non-null    object
#  131  toilets:emptying                       107 non-null    object
#  132  toilets:tank                           108 non-null    object
#  133  toilets:technology                     108 non-null    object
#  134  addr:place                             19 non-null     object
#  135  operational                            1 non-null      object
#  136  power                                  1 non-null      object
#  137  phone:business                         7 non-null      object
#  138  email                                  3 non-null      object
#  139  composting                             19 non-null     object
#  140  sym                                    6 non-null      object
#  141  time                                   5 non-null      object
#  142  toilet                                 5 non-null      float64
#  143  commune                                10 non-null     object
#  144  departement                            41 non-null     object
#  145  section                                4 non-null      object
#  146  hot_water                              15 non-null     object
#  147  note:toilets:hands_drying              1 non-null      object
#  148  toilets:hands_drying                   21 non-null     object
#  149  etat                                   43 non-null     object
#  150  pcode                                  1 non-null      float64
#  151  material                               7 non-null      object
#  152  survey:date                            43 non-null     object
#  153  geometry_source_name                   2 non-null      object
#  154  geometry_source_type                   5 non-null      object
#  155  opening_hours:covid19                  25 non-null     object
#  156  type                                   6 non-null      object
#  157  building:levels                        15 non-null     object
#  158  drinking_water:seasonal                2 non-null      object
#  159  attribute_source_type                  4 non-null      object
#  160  changing_table:fee                     22 non-null     object
#  161  changing_table:location                44 non-null     object
#  162  building:material                      4 non-null      object
#  163  building:roof                          3 non-null      object
#  164  building_status                        3 non-null      object
#  165  toilet_bad                             2 non-null      float64
#  166  toilet_good                            2 non-null      float64
#  167  cmt                                    4 non-null      object
#  168  capacity:seats                         1 non-null      float64
#  169  capacity:standing                      1 non-null      float64
#  170  contact:person                         1 non-null      object
#  171  contact:phone                          3 non-null      object
#  172  name:fr                                3 non-null      object
#  173  power_source                           1 non-null      object
#  174  practicability                         1 non-null      object
#  175  barrier:key                            1 non-null      object
#  176  toilets_durability                     73 non-null     object
#  177  check_date:opening_hours               3 non-null      object
#  178  project                                39 non-null     object
#  179  source_date                            64 non-null     object
#  180  source_type_GPS                        64 non-null     object
#  181  source_type_survey                     65 non-null     object
#  182  toilets_access                         71 non-null     object
#  183  toilets_technology                     66 non-null     object
#  184  pitlatrine                             11 non-null     object
#  185  cosmha                                 2 non-null      object
#  186  source_type_imagery                    2 non-null      object
#  187  source_type_walking_paper              2 non-null      object
#  188  review                                 3 non-null      object
#  189  door:opener                            1 non-null      object
#  190  door:power                             1 non-null      object
#  191  door:threshhold                        1 non-null      object
#  192  door:width                             1 non-null      object
#  193  elevation                              1 non-null      float64
#  194  changing_table:count                   31 non-null     float64
#  195  men                                    7 non-null      object
#  196  source2                                1 non-null      object
#  197  room                                   25 non-null     object
#  198  gender                                 10 non-null     object
#  199  floor                                  2 non-null      float64
#  200  comment                                2 non-null      object
#  201  noexit                                 4 non-null      object
#  202  source:name                            1 non-null      object
#  203  is_in:state_code                       3 non-null      object
#  204  is_in:city                             2 non-null      object
#  205  is_in:state                            2 non-null      object
#  206  handwashing                            2 non-null      object
#  207  network                                11 non-null     object
#  208  covered                                14 non-null     object
#  209  condition                              244 non-null    object
#  210  toilets:unisex                         33 non-null     object
#  211  short_name:operator                    1 non-null      object
#  212  abandoned                              89 non-null     object
#  213  emergency                              96 non-null     object
#  214  seamark:small_craft_facility:category  16 non-null     object
#  215  seamark:type                           16 non-null     object
#  216  fee:amount                             1 non-null      object
#  217  payment:cash                           6 non-null      object
#  218  bicycle                                1 non-null      object
#  219  foot                                   2 non-null      object
#  220  disused                                98 non-null     object
#  221  buildingpart                           1 non-null      object
#  222  wetap:status                           16 non-null     object
#  223  wetap:bottle                           1 non-null      object
#  224  wetap:statusnote                       3 non-null      object
#  225  wetap:photo                            1 non-null      object
#  226  World_Concern:project                  12 non-null     object
#  227  contact                                1 non-null      object
#  228  survey_information_access              6 non-null      object
#  229  cabine                                 1 non-null      float64
#  230  undefined                              8 non-null      object
#  231  internet_access:fee                    1 non-null      object
#  232  lit                                    28 non-null     object
#  233  wetap:credit                           2 non-null      object
#  234  stroller                               1 non-null      object
#  235  nursing_room                           3 non-null      object
#  236  waste_basket                           2 non-null      object
#  237  location                               14 non-null     object
#  238  shelter_type                           3 non-null      object
#  239  disposal                               13 non-null     object
#  240  level:ref                              10 non-null     object
#  241  toilets:occupancy                      5 non-null      object
#  242  stink                                  4 non-null      object
#  243  gnis:county_name                       1 non-null      object
#  244  gnis:import_uuid                       1 non-null      object
#  245  gnis:reviewed                          1 non-null      object
#  246  TDH_Lausanne                           3 non-null      object
#  247  source:date                            3 non-null      object
#  248  backcountry                            633 non-null    object
#  249  generator:source                       1 non-null      object
#  250  power_supply                           6 non-null      object
#  251  tents                                  628 non-null    object
#  252  addr:province                          48 non-null     object
#  253  service:bicycle:cleaning               1 non-null      object
#  254  service:bicycle:diy                    1 non-null      object
#  255  service:bicycle:pump                   2 non-null      object
#  256  service:bicycle:rental                 1 non-null      object
#  257  service:bicycle:repair                 1 non-null      object
#  258  service:bicycle:retail                 1 non-null      object
#  259  service:bicycle:second_hand            1 non-null      object
#  260  maxtents                               602 non-null    object
#  261  openfire                               603 non-null    object
#  262  2tag                                   3 non-null      object
#  263  place                                  9 non-null      object
#  264  position                               6 non-null      object
#  265  service                                4 non-null      object
#  266  source:position                        10 non-null     object
#  267  note_2                                 1 non-null      object
#  268  contact:website                        2 non-null      object
#  269  capacity:disabled                      1 non-null      float64
#  270  natural                                1 non-null      object
#  271  toilets:number                         8 non-null      float64
#  272  addr:floor                             23 non-null     object
#  273  toilets:female                         2 non-null      object
#  274  toilets:male                           2 non-null      object
#  275  check_date:wheelchair                  4 non-null      object
#  276  drinking_water:bottle                  1 non-null      object
#  277  water_supply                           1 non-null      object
#  278  survey                                 1 non-null      object
#  279  rooms                                  1 non-null      object
#  280  caravans                               3 non-null      object
#  281  name:en                                5 non-null      object
#  282  informal                               1 non-null      object
#  283  name:es                                3 non-null      object
#  284  baby_feeding                           19 non-null     object
#  285  addr:district                          50 non-null     object
#  286  addr:unit                              17 non-null     object
#  287  permit                                 9 non-null      object
#  288  charge                                 27 non-null     object
#  289  count                                  1 non-null      float64
#  290  office                                 1 non-null      object
#  291  opening_hours:wheelchair               1 non-null      object
#  292  alt_name                               2 non-null      object
#  293  family                                 3 non-null      object
#  294  camp_site                              1 non-null      object
#  295  addr:suburb                            11 non-null     object
#  296  smoking                                10 non-null     object
#  297  traildock:user                         1 non-null      object
#  298  water                                  1 non-null      object
#  299  operator:fr                            1 non-null      object
#  300  url                                    5 non-null      object
#  301  gender_segregated                      69 non-null     object
#  302  handwashing:hand_disinfection          6 non-null      object
#  303  handwashing:soap                       36 non-null     object
#  304  surface                                8 non-null      object
#  305  second_chance_youth                    1 non-null      object
#  306  construction                           1 non-null      object
#  307  postal_code                            1 non-null      float64
#  308  door                                   5 non-null      object
#  309  toilets:num_chambers                   2 non-null      float64
#  310  toilets:disabled                       1 non-null      object
#  311  service:bicycle:tools                  1 non-null      object
#  312  handrail                               2 non-null      object
#  313  addr:flats                             1 non-null      float64
#  314  colour                                 21 non-null     object
#  315  smell                                  2 non-null      object
#  316  artist_name                            1 non-null      object
#  317  payment:coins                          5 non-null      object
#  318  toilets:hand_drying                    12 non-null     object
#  319  toilets:hot_water                      3 non-null      object
#  320  repeat_on                              5 non-null      object
#  321  locker                                 2 non-null      object
#  322  reg                                    1 non-null      object
#  323  addr:town                              1 non-null      object
#  324  note:opening_hours                     1 non-null      object
#  325  opening_hours:rubbish                  1 non-null      object
#  326  disabled                               1 non-null      object
#  327  levels                                 2 non-null      object
#  328  air_conditioning                       1 non-null      object
#  329  sport                                  1 non-null      object
#  330  direction                              2 non-null      float64
#  331  height                                 2 non-null      float64
#  332  planned:building                       1 non-null      object
#  333  ele:ellipsoid                          7 non-null      float64
#  334  health_facility:type                   1 non-null      object
#  335  start_date                             46 non-null     object
#  336  heating                                1 non-null      object
#  337  water_source                           1 non-null      object
#  338  changing_table:brand                   1 non-null      object
#  339  water fountain                         1 non-null      object
#  340  bottle                                 2 non-null      object
#  341  paper_supplied                         2 non-null      object
#  342  source:amenity                         2 non-null      object
#  343  operator:phone                         1 non-null      object
#  344  addr:neighbourhood                     7 non-null      object
#  345  nohousenumber                          3 non-null      object
#  346  toilets:handwashing:hand_disinfection  1 non-null      object
#  347  building:floor                         1 non-null      float64
#  348  hiking                                 1 non-null      object
#  349  mtb                                    1 non-null      object
#  350  ski                                    1 non-null      object
#  351  source:website                         65 non-null     object
#  352  description:covid19                    1 non-null      object
#  353  instore                                1 non-null      object
#  354  cash_withdrawal                        1 non-null      object
#  355  payment:american_express               1 non-null      object
#  356  payment:credit_cards                   2 non-null      object
#  357  payment:debit_cards                    1 non-null      object
#  358  payment:discover_card                  1 non-null      object
#  359  payment:mastercard                     1 non-null      object
#  360  payment:visa                           2 non-null      object
#  361  seats                                  1 non-null      float64
#  362  locked                                 1 non-null      object
#  363  toilet:handwashing                     1 non-null      object
#  364  image                                  4 non-null      object
#  365  contact:email                          43 non-null     object
#  366  end_date                               43 non-null     object
#  367  operator:website                       43 non-null     object
#  368  sanitary_supply                        1 non-null      object
#  369  note:access                            1 non-null      object
#  370  wikipedia                              1 non-null      object
#  371  gender_neutral                         1 non-null      object
#  372  payment:none                           1 non-null      object
#  373  lined                                  1 non-null      object
#  374  nycdoitt:bin                           1 non-null      float64
#  375  key                                    1 non-null      object
#  376  segregated                             1 non-null      object
#  377  source:data                            1 non-null      object
#  378  mirror                                 1 non-null      object
#  379  socket:nema_5_15                       1 non-null      float64
# dtypes: float64(34), int64(1), object(345)
# memory usage: 128.9+ MB

# %%
df.head()
#this shows the first 5 rows of a dataset by default
#try adding a number between the () and rerunning this block
# Out:
#          id        lat         lon         state  \
# 0  20954425  34.118113 -118.294582    California
# 1  21652941  43.421768  -80.319487       Ontario
# 2  25620321  40.755436  -75.260307  Pennsylvania
# 3  29946571  40.685482 -121.418994    California
# 4  31319629  38.613944  -78.705993      Virginia
#
#                                              address         city      zip  \
# 0  Boy Scout Road, Los Angeles, California 90027,...  Los Angeles    90027
# 1  169 Bechtel Street, Cambridge, Ontario N3C 1Z8...    Cambridge  N3C 1Z8
# 2  111 Main Street, Easton, Pennsylvania 18083, U...       Easton    18083
# 3  Subway Caves, Old Station, California 96071, U...  Old Station    96071
# 4  262000 Interstate 81, Timberville, Virginia 22...  Timberville    22853
#
#          country  amenity toilets:wheelchair  ... wikipedia gender_neutral  \
# 0  United States  toilets                yes  ...       NaN            NaN
# 1         Canada  toilets                NaN  ...       NaN            NaN
# 2  United States  toilets                NaN  ...       NaN            NaN
# 3  United States  toilets                NaN  ...       NaN            NaN
# 4  United States  toilets                NaN  ...       NaN            NaN
#
#   payment:none lined nycdoitt:bin  key segregated source:data mirror  \
# 0          NaN   NaN          NaN  NaN        NaN         NaN    NaN
# 1          NaN   NaN          NaN  NaN        NaN         NaN    NaN
# 2          NaN   NaN          NaN  NaN        NaN         NaN    NaN
# 3          NaN   NaN          NaN  NaN        NaN         NaN    NaN
# 4          NaN   NaN          NaN  NaN        NaN         NaN    NaN
#
#   socket:nema_5_15
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 380 columns]

# %%
df.sample(10)
#this shows a random sample of (X) number of rows, 1 by default
#try rerunning a few times to see diffrent parts of the dataset
# Out:
#                 id        lat         lon          state  \
# 44374  11025599141  41.914146  -70.570509  Massachusetts
# 5993    1919407851  32.727500 -117.148871     California
# 32558   7906592285  -1.548985  -79.533939       Los Ríos
# 6394    2020854222  33.921352 -117.473712     California
# 2498    1114434268  40.557079  -74.263161     New Jersey
# 4848    1690218964  39.067766  -86.410579        Indiana
# 25298   6090641574  29.527420  -98.470326          Texas
# 26958   6564883252  44.217512  -87.507986      Wisconsin
# 16872   4300880582  29.592911  -97.585495          Texas
# 1757     883283356  39.447746  -76.632029       Maryland
#
#                                                  address  \
# 44374  Maintenance Road, Plymouth, Massachusetts 0236...
# 5993   Centro Cultural De La Raza, 2125 Park Blvd, Sa...
# 32558   24 De Mayo Puebloviejo - Los Ríos, 1202, Ecuador
# 6394   4540 Meredith Street, Riverside, California 92...
# 2498   Nathan's, NJ Turnpike, Mile Marker 93, Sewaren...
# 4848   5505 Indiana Highway 446, Bloomington, Indiana...
# 25298  Gate A7, 9800 Airport Blvd, San Antonio, Texas...
# 26958  1 Parkside Road, Two Rivers, Wisconsin 54241, ...
# 16872  Palmetto State Park, 78 Park Road 11 S, Gonzal...
# 1757   Maryland State Fair Birthing Center, Luthervil...
#
#                        city    zip        country  amenity toilets:wheelchair  \
# 44374              Plymouth  02360  United States  toilets                NaN
# 5993              San Diego  92101  United States  toilets                NaN
# 32558           Puebloviejo   1202        Ecuador  toilets                NaN
# 6394              Riverside  92505  United States  toilets                NaN
# 2498                Sewaren  07077  United States  toilets                NaN
# 4848            Bloomington  47401  United States  toilets                NaN
# 25298           San Antonio  78216  United States  toilets                NaN
# 26958            Two Rivers  54241  United States  toilets                NaN
# 16872              Gonzales  78629  United States  toilets                NaN
# 1757   Lutherville Timonium  21093  United States  toilets                NaN
#
#        ... wikipedia gender_neutral payment:none lined nycdoitt:bin  key  \
# 44374  ...       NaN            NaN          NaN   NaN          NaN  NaN
# 5993   ...       NaN            NaN          NaN   NaN          NaN  NaN
# 32558  ...       NaN            NaN          NaN   NaN          NaN  NaN
# 6394   ...       NaN            NaN          NaN   NaN          NaN  NaN
# 2498   ...       NaN            NaN          NaN   NaN          NaN  NaN
# 4848   ...       NaN            NaN          NaN   NaN          NaN  NaN
# 25298  ...       NaN            NaN          NaN   NaN          NaN  NaN
# 26958  ...       NaN            NaN          NaN   NaN          NaN  NaN
# 16872  ...       NaN            NaN          NaN   NaN          NaN  NaN
# 1757   ...       NaN            NaN          NaN   NaN          NaN  NaN
#
#       segregated source:data mirror socket:nema_5_15
# 44374        NaN         NaN    NaN              NaN
# 5993         NaN         NaN    NaN              NaN
# 32558        NaN         NaN    NaN              NaN
# 6394         NaN         NaN    NaN              NaN
# 2498         NaN         NaN    NaN              NaN
# 4848         NaN         NaN    NaN              NaN
# 25298        NaN         NaN    NaN              NaN
# 26958        NaN         NaN    NaN              NaN
# 16872        NaN         NaN    NaN              NaN
# 1757         NaN         NaN    NaN              NaN
#
# [10 rows x 380 columns]

# %%
df.state
#this refrences a series of all the states/provences in order that they appear in the data
# Out:
# 0         California
# 1            Ontario
# 2       Pennsylvania
# 3         California
# 4           Virginia
#            ...
# 494       California
# 495       California
# 496       Washington
# 497       Washington
# 498    New Hampshire
# Name: state, Length: 499, dtype: object

# %%
#if you wanna look at just a few columns of the dataset, try this
df[["id", "address", "note"]]
# Out:
#                 id                                            address  \
# 0         20954425  Boy Scout Road, Los Angeles, California 90027,...
# 1         21652941  169 Bechtel Street, Cambridge, Ontario N3C 1Z8...
# 2         25620321  111 Main Street, Easton, Pennsylvania 18083, U...
# 3         29946571  Subway Caves, Old Station, California 96071, U...
# 4         31319629  262000 Interstate 81, Timberville, Virginia 22...
# ...            ...                                                ...
# 44465  11037553730  17602 Indiana Highway 10, Culver, Indiana 4651...
# 44466  11037553731  16968 Sycamore Road, Culver, Indiana 46511, Un...
# 44467  11037708185  Brew Devils, Memorial Student Center - Lower L...
# 44468  11037708186  Brew Devils, Memorial Student Center - Lower L...
# 44469  11038019462  Deer Park Road, Port Angeles, Washington 98362...
#
#            note
# 0           NaN
# 1      seasonal
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 44465       NaN
# 44466       NaN
# 44467       NaN
# 44468       NaN
# 44469       NaN
#
# [44470 rows x 3 columns]

# %% [markdown]
# You may notice that this data isn't perfect, not every toilet has a value for every column. This is very common in the real world, and is often caused when different people or organizations encode data differently. This problem is why the first step in a data analysis is often **data cleaning and validation**.
#
#
# This step helps us understand what information is available in the data, so we can brainstorm options for how to use it in a project. There are many ways to do this, but one of the easiest ways is to use string matching functions to search the dataset.

# %%
#this creates a series of boolean values depending on if the value at that row fulfills the test
#in this case the test is if the `state` field contains the word "New"
df.state.str.contains("New", na=False)

# %%
df[df.state.str.contains("New", na=False)] #we can then filter the df like this

# %%
#and we can combine filters with the binary operators that we saw earlier
df[df.state.str.contains("New", na=False) & df.state.str.contains("York", na=False)]

# %%
#or we can also write the above function like this instead
df[df.state.str.match("New York", na=False)]

# %%
#you can also exclude data that matches the condition with a - (minus) sign
df[-df.state.str.match("New York", na=False)]

# %%
#or just check if a row has a value at all, with the function .isna()
#this function returns true if the value is NaN (Stands for Not a Number)
df[-df["gender_neutral"].isna()]

# %% [markdown]
# ###Now that you've gotten a taste of filtering and navigating the dataset, time to play....
#
# ## ... I Spy!
# Below are some challenges, see if you can write filters that help you find the same sets of bathrooms that I found.
#
#
# > **Hint:** Use `df.info(verbose=True, show_counts=True)` to see what possible column names you can explore
#
#
# > **Optional Challenge:** If your looking for a challenge, try using regular expressions to write the filters [here's some guidance](https://www.rexegg.com/regex-quickstart.html)

# %% [markdown]
# ### I Spy.... 17 bathrooms that are in bad condition

# %%
#write your code here
df[df["status"].str.contains("bad") | -df["toilet_bad"].isna() ]

# %% [markdown]
# ### I Spy.... 3914 bathrooms that are disability or wheelchair accessible

# %%
#write your code here
df[ df["toilets:wheelchair"].str.contains("yes", na = False) | df.wheelchair.str.contains("yes", na = False) | df.disability_access.str.contains("yes", na = False)| df.handicap.str.contains("yes", na = False)  | -df["opening_hours:wheelchair"].isna() ][["toilets:wheelchair", "wheelchair", "opening_hours:wheelchair", "disability_access", "handicap"]]

# %% [markdown]
# ### I Spy.... 43 bathrooms at Burning Man

# %%
#write your code here
df[df["contact:email"].str.contains("@", na=False)]["contact:email"]

# %% [markdown]
# ### I Spy.... something you find interesting!
# Your turn, find some interesting collection of bathrooms in the dataset (or a few) and show them here, Don’t forget to share them with your group!

# %%
#write your code here

# %% [markdown]
# # Challenge #2: Cluster? I hardly know her
#
#
# **K-mode clustering** is a machine-learning technique used to group a set of data objects into a specified number of **clusters** (or categories), based on their attributes. This method can be used to find interesting patterns and relationships in the data. By understanding how some bathrooms are related to each other we might find interesting outliers or similarities that we wouldn't have noticed otherwise.
#
#
# We're going to test this with our bathroom dataset, and the first step is installing and importing some packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install kmodes
from kmodes.kmodes import KModes
# Out:
# Requirement already satisfied: kmodes in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.2.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.1.0)

# %% [markdown]
# Next, we need to clean our data. This can be done with some simple filtering like we did earlier. The data cannot have any NA values, so select a few columns that you think are interesting and have a good number of shared rows, and filter the data so it's just those rows
#
#
# > **Hint**: if your having trouble, try the `.dropna()` funcution, I used it like this `filtered = df[["changing_table", "state", "wheelchair"]].dropna()` to create my dataframe

# %%
filtered = df[["changing_table", "state", "wheelchair"]].dropna()

# %% [markdown]
# Now, we're gonna slightly reformat that dataframe by converting it to a **Numpy array**. This is a special type of data structure that is often used in Machine Learning

# %%
filtered.reset_index(drop=True, inplace=True) #so our indexes go 1, 2, 3...
data = filtered.to_numpy()
data

# %% [markdown]
# Before we can cluster our data we need to learn what the ideal number of groups (clusters) for our dataset is. One way we do that is by creating an **elbow curve** in what's called the **elbow method**.
#
#
# The elbow method test different cluster sizes, in this case 1-9 and tracks a measure called **cluster variance**. As the number of clusters increase the **cluster variance** decreases at first rapidly, then more gradually. Once it becomes gradual or near constant, that is the ideal number of clusters for a dataset. When graphed this looks like a bent elbow and the point that is the elbow is what we will use when we cluster the data.
#
#
# Below we are going to run the elbow method and graph an elbow curve. See if you can identify the elbow point on the graph
#
#
# > **Hint:** the ideal number will also print out

# %%
# Elbow curve to find optimal K
cost = []
K = range(1,10)
for k in list(K):
    kmode = KModes(n_clusters=k, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(data)
    cost.append(kmode.cost_)

plt.plot(K, cost, 'x-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Curve')
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 2277.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 2277.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 2277.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 2277.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 2277.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 50, cost: 1683.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 54, cost: 1697.0
# Run 2, iteration: 2/100, moves: 0, cost: 1697.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 2231.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 43, cost: 1683.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 103, cost: 2040.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 317, cost: 1394.0
# Run 1, iteration: 2/100, moves: 249, cost: 1376.0
# Run 1, iteration: 3/100, moves: 19, cost: 1376.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 18, cost: 1365.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 100, cost: 1353.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 467, cost: 1419.0
# Run 4, iteration: 2/100, moves: 266, cost: 1419.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 34, cost: 1693.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 111, cost: 1339.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 284, cost: 1368.0
# Run 2, iteration: 2/100, moves: 13, cost: 1368.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 331, cost: 1373.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 72, cost: 1605.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 328, cost: 1346.0
# Run 5, iteration: 2/100, moves: 27, cost: 1346.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 360, cost: 1287.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 335, cost: 1237.0
# Run 2, iteration: 2/100, moves: 11, cost: 1237.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 733, cost: 1205.0
# Run 3, iteration: 2/100, moves: 0, cost: 1205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 378, cost: 1298.0
# Run 4, iteration: 2/100, moves: 36, cost: 1298.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 1287.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 170, cost: 1187.0
# Run 1, iteration: 2/100, moves: 12, cost: 1187.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 84, cost: 1284.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 76, cost: 1320.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 300, cost: 1231.0
# Run 4, iteration: 2/100, moves: 25, cost: 1231.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 79, cost: 1287.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 375, cost: 1213.0
# Run 1, iteration: 2/100, moves: 2, cost: 1213.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 133, cost: 1135.0
# Run 2, iteration: 2/100, moves: 0, cost: 1135.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 57, cost: 1266.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 35, cost: 1208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 99, cost: 1213.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 333, cost: 1159.0
# Run 1, iteration: 2/100, moves: 1, cost: 1159.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 412, cost: 1143.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 69, cost: 1154.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 107, cost: 1100.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 148, cost: 1142.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 133, cost: 1150.0
# Run 1, iteration: 2/100, moves: 10, cost: 1150.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 406, cost: 1082.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 350, cost: 1076.0
# Run 3, iteration: 2/100, moves: 3, cost: 1076.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 158, cost: 1077.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 344, cost: 1160.0
# Best run was number 3

# %% [markdown]
# Finally, update the below function with the Ideal number of clusters that we calculated above and run the prediction model.
#
#
# * The `KModes()` function creates an untrained machine learning model for K-Modes clustering.
# * The `fit_predict()` function, when invoked on an untrained model, takes a numpy array containing data as its input, trains the machine learning model, and classifies each data point as part of a cluster.
# * To end we will add a new column to our original filtered data frame that says what cluster each bathroom belongs to

# %%
number_of_clusters = 3
kmode = KModes(n_clusters=number_of_clusters, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(data)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 10, cost: 1649.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 44, cost: 1520.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 374, cost: 1523.0
# Run 3, iteration: 2/100, moves: 3, cost: 1523.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 321, cost: 1649.0
# Run 4, iteration: 2/100, moves: 13, cost: 1649.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 19, cost: 1796.0
# Best run was number 2

# %%
filtered['cluster']=pd.Series(clusters)
filtered

# %% [markdown]
# **You did it!** Now you can go back and try it with another set of columns or you can explore the clusters by changing the filter below.
#
#
# **In your groups talk about what separates each cluster, and if these relationships tell you anything interesting about the public restrooms in the dataset.**

# %%
filtered[filtered.cluster == 0]
# Out:
#      changing_table             state wheelchair  cluster
# 0                no              Ohio        yes        0
# 5                no  British Columbia        yes        0
# 8                no            Quebec         no        0
# 10               no           Georgia         no        0
# 12               no     Massachusetts         no        0
# ...             ...               ...        ...      ...
# 1335             no        New Jersey         no        0
# 1336             no  British Columbia         no        0
# 1337             no         Minnesota        yes        0
# 1338             no          Maryland        yes        0
# 1341             no             Idaho         no        0
#
# [715 rows x 4 columns]
